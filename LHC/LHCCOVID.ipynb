# %% [markdown]
# <a href="https://colab.research.google.com/github/joshtrivedi/Machine-Learning/blob/main/LHC/LHCCOVID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  #helps in mathematical operations
import matplotlib.pyplot as plt #helps in plotting of graph
import pandas as pd #helps in making dataframes and importing csv files

# %%
from google.colab import drive #to import google drive data

# %%
drive.mount('/content/drive') # mount the drive on colab using authentication
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/"My Drive/Colab Notebooks/Files"
# Out:
# /content/drive/My Drive/Colab Notebooks/Files

# %%
confirmedcases = pd.read_csv("time_series_covid19_confirmed_global.csv")
recoveredcases = pd.read_csv("time_series_covid19_recovered_global.csv")
deaths = pd.read_csv("time_series_covid19_deaths_global.csv")
confirmedcases = confirmedcases.drop(['Province/State','Lat','Long'],axis=1)
recoveredcases = recoveredcases.drop(['Province/State','Lat','Long'],axis=1)
deaths = deaths.drop(['Province/State','Lat','Long'],axis=1)

# %% [markdown]
# TASK 1

# %%
indiaconfirmedcases = confirmedcases.loc[confirmedcases['Country/Region']=='India']

# %%
indiarecoveredcases = recoveredcases.loc[recoveredcases['Country/Region']=='India']
indiadeathcases = deaths.loc[deaths['Country/Region']=='India']

# %%
indiaconfirmedcases = pd.DataFrame(indiaconfirmedcases)
indiarecoveredcases = pd.DataFrame(indiarecoveredcases)
indiadeathcases = pd.DataFrame(indiadeathcases)

# %%
indiaconfirmedcases=indiaconfirmedcases.drop(['Country/Region'],axis=1)
indiarecoveredcases=indiarecoveredcases.drop(['Country/Region'],axis=1)
indiadeathcases = indiadeathcases.drop(['Country/Region'],axis=1)

# %%
indiaconfirmedcases.index = ["Confirm_Cases"]
indiaconfirmedcases = indiaconfirmedcases.transpose()

# %%
indiaconfirmedcases
# Out:
#          Confirm_Cases
# 1/22/20              0
# 1/23/20              0
# 1/24/20              0
# 1/25/20              0
# 1/26/20              0
# ...                ...
# 4/29/21       18762976
# 4/30/21       19164969
# 5/1/21        19557457
# 5/2/21        19925517
# 5/3/21        19925604
#
# [468 rows x 1 columns]

# %%
indiarecoveredcases.index = ["Recovered_Cases"]
indiarecoveredcases = indiarecoveredcases.transpose()
indiadeathcases.index = ["Deaths"]
indiadeathcases = indiadeathcases.transpose()

# %%
indiadata = indiaconfirmedcases

# %%
indiadata['Recovered_Cases'] = indiarecoveredcases

# %%
indiadata['Deaths'] = indiadeathcases

# %%
indiadata
# Out:
#          Confirm_Cases  Recovered_Cases  Deaths
# 1/22/20              0                0       0
# 1/23/20              0                0       0
# 1/24/20              0                0       0
# 1/25/20              0                0       0
# 1/26/20              0                0       0
# ...                ...              ...     ...
# 4/29/21       18762976         15384418  208330
# 4/30/21       19164969         15684406  211853
# 5/1/21        19557457         15992271  215542
# 5/2/21        19925517         16292725  218959
# 5/3/21        19925604         16293003  218959
#
# [468 rows x 3 columns]

# %%
plt.plot(indiadata.index, indiadata['Confirm_Cases'], label = "Confirmed Cases", linestyle="-")
plt.plot(indiadata.index, indiadata['Recovered_Cases'], label = "Recovered Cases", linestyle="--")
plt.plot(indiadata.index, indiadata['Deaths'], label = "Deaths", linestyle="-.")
plt.xlabel("Days")
plt.ylabel("Number of Cases")
plt.title("Indian Covid Cases")
plt.legend()
plt.show()

# %%
usconfirmedcases = confirmedcases.loc[confirmedcases['Country/Region']=='US']
usconfirmedcases
# Out:
#     Country/Region  1/22/20  1/23/20  ...    5/1/21    5/2/21    5/3/21
# 250             US        1        1  ...  32392274  32421641  32470920
#
# [1 rows x 469 columns]

# %% [markdown]
# Task 2

# %%
usrecoveredcases = recoveredcases.loc[recoveredcases['Country/Region']=='US']
usdeathcases = deaths.loc[deaths['Country/Region']=='US']

# %%
usconfirmedcases = pd.DataFrame(usconfirmedcases)
usrecoveredcases = pd.DataFrame(usrecoveredcases)
usdeathcases = pd.DataFrame(usdeathcases)

# %%
usconfirmedcases=usconfirmedcases.drop(['Country/Region'],axis=1)
usrecoveredcases=usrecoveredcases.drop(['Country/Region'],axis=1)
usdeathcases = usdeathcases.drop(['Country/Region'],axis=1)

# %%
usconfirmedcases.index = ["Confirm_Cases"]
usconfirmedcases = usconfirmedcases.transpose()

# %%
usconfirmedcases
# Out:
#          Confirm_Cases
# 1/22/20              1
# 1/23/20              1
# 1/24/20              2
# 1/25/20              2
# 1/26/20              5
# ...                ...
# 4/29/21       32289049
# 4/30/21       32346971
# 5/1/21        32392274
# 5/2/21        32421641
# 5/3/21        32470920
#
# [468 rows x 1 columns]

# %%
usrecoveredcases.index = ["Recovered_Cases"]
usrecoveredcases = usrecoveredcases.transpose()
usdeathcases.index = ["Deaths"]
usdeathcases = usdeathcases.transpose()

# %%
usdata = usconfirmedcases

# %%
usdata['Recovered_Cases'] = usrecoveredcases

# %%
usdata['Deaths'] = usdeathcases

# %%
usdata
# Out:
#          Confirm_Cases  Recovered_Cases  Deaths
# 1/22/20              1                0       0
# 1/23/20              1                0       0
# 1/24/20              2                0       0
# 1/25/20              2                0       0
# 1/26/20              5                0       0
# ...                ...              ...     ...
# 4/29/21       32289049                0  575290
# 4/30/21       32346971                0  576328
# 5/1/21        32392274                0  576722
# 5/2/21        32421641                0  577045
# 5/3/21        32470920                0  577500
#
# [468 rows x 3 columns]

# %%
plt.plot(usdata.index, usdata['Confirm_Cases'], label = "Confirmed Cases", linestyle="-")
plt.plot(usdata.index, usdata['Recovered_Cases'], label = "Recovered Cases", linestyle="--")
plt.plot(usdata.index, usdata['Deaths'], label = "Deaths", linestyle="-.")
plt.xlabel("Days")
plt.ylabel("Number of Cases")
plt.title("US Covid Cases")
plt.legend()
plt.show()

# %% [markdown]
# TASK 3

# %%
from sklearn.linear_model import LinearRegression

# %%
X_features = np.array(range(1,469))
X_features = X_features.reshape(-1,1)
Y = np.array(indiaconfirmedcases['Confirm_Cases'])
Y = Y.reshape(-1,1)

# %%
x= np.array([469]).reshape(-1,1)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 10)
X_poly = poly.fit_transform(X_features)
poly = poly.fit(X_poly, Y)
lin2 = LinearRegression()
lin2.fit(X_poly, Y)
ans2 =int(lin2.predict(poly.fit_transform(x))) 
print(" the number of covid cases on 4th May, 2021:",ans2)
# Out:
#  the number of covid cases on 4th May, 2021: 20245941

# %%
casetoday=ans2- Y[-1]

# %%
casetoday
# Out:
# array([320337])

# %%
import os
import glob
location="LHC"

file_name=[]
for file in os.listdir(location):
        file_name.append(file)
      
print(file_name)
combinedCSV=pd.concat([pd.read_csv("LHC/"+f) for f in file_name])
combinedCSV.to_csv("combineddata.csv",index=False,encoding='utf-8-sig')
# Out:
# ['03-01-2021.csv', '03-05-2021.csv', '03-04-2021.csv', '03-02-2021.csv', '03-03-2021.csv', '03-06-2021.csv', '03-07-2021.csv', '03-08-2021.csv', '03-09-2021.csv', '03-10-2021.csv', '03-11-2021.csv', '03-12-2021.csv', '03-13-2021.csv', '03-14-2021.csv', '03-15-2021.csv', '03-17-2021.csv', '03-16-2021.csv', '03-19-2021.csv', '03-20-2021.csv', '03-18-2021.csv', '03-21-2021.csv', '03-22-2021.csv', '03-23-2021.csv', '03-24-2021.csv', '03-25-2021.csv', '03-26-2021.csv', '03-28-2021.csv', '03-27-2021.csv', '03-30-2021.csv', '03-29-2021.csv', '03-31-2021.csv', '04-01-2021.csv', '04-02-2021.csv', '04-03-2021.csv', '04-04-2021.csv', '04-07-2021.csv', '04-05-2021.csv', '04-06-2021.csv', '04-10-2021.csv', '04-09-2021.csv', '04-08-2021.csv', '04-13-2021.csv', '04-11-2021.csv', '04-14-2021.csv', '04-12-2021.csv', '04-17-2021.csv', '04-15-2021.csv', '04-16-2021.csv', '04-20-2021.csv', '04-19-2021.csv', '04-18-2021.csv', '04-22-2021.csv', '04-25-2021.csv', '04-23-2021.csv', '04-21-2021.csv', '04-24-
# ...

# %%
combinedCSV
# Out:
#       FIPS Admin2  ... Incident_Rate Case_Fatality_Ratio
# 0      NaN    NaN  ...    143.168187            4.385194
# 1      NaN    NaN  ...   3750.469108            1.682556
# 2      NaN    NaN  ...    258.272078            2.637411
# 3      NaN    NaN  ...  14093.056364            1.010194
# 4      NaN    NaN  ...     63.451074            2.435984
# ...    ...    ...  ...           ...                 ...
# 3978   NaN    NaN  ...      3.042987            1.181634
# 3979   NaN    NaN  ...   5834.419306            1.099322
# 3980   NaN    NaN  ...     21.259997           19.444883
# 3981   NaN    NaN  ...    498.766424            1.366517
# 3982   NaN    NaN  ...    257.560304            4.101251
#
# [254912 rows x 14 columns]

# %% [markdown]
# TASK 4

# %%
gujaratdata = combinedCSV.loc[combinedCSV['Province_State']=='Gujarat']
gujaratdata
# Out:
#      FIPS Admin2  ... Incident_Rate Case_Fatality_Ratio
# 259   NaN    NaN  ...    423.212537            1.631424
# 259   NaN    NaN  ...    426.224792            1.620996
# 259   NaN    NaN  ...    425.418497            1.623700
# 259   NaN    NaN  ...    423.923329            1.629058
# 259   NaN    NaN  ...    424.666999            1.626574
# ..    ...    ...  ...           ...                 ...
# 259   NaN    NaN  ...    888.923868            1.265109
# 259   NaN    NaN  ...    910.603029            1.264563
# 259   NaN    NaN  ...    866.057967            1.267237
# 259   NaN    NaN  ...    930.921665            1.262693
# 259   NaN    NaN  ...    930.921665            1.262693
#
# [64 rows x 14 columns]

# %%
plt.plot(gujaratdata['Last_Update'], gujaratdata['Confirmed'], label = "Confirmed Cases", linestyle="-")
plt.plot(gujaratdata['Last_Update'], gujaratdata['Recovered'], label = "Recovered Cases", linestyle="--")
plt.plot(gujaratdata['Last_Update'], gujaratdata['Deaths'], label = "Deaths", linestyle="-.")
plt.xlabel("Days")
plt.ylabel("Number of Cases")
plt.title("Gujarat Covid Cases")
plt.legend()
plt.show()

# %% [markdown]
# TASK 5

# %%
from sklearn.linear_model import LinearRegression
X_Gujfeatures = np.array(range(1,65))
X_Gujfeatures = X_Gujfeatures.reshape(-1,1)
YGuj = np.array(gujaratdata['Confirmed'])
YGuj = Y_Guj.reshape(-1,1)
X_Gujfeatures.size
# Out:
# 64

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 5)
X_poly = poly.fit_transform(X_Gujfeatures)
poly = poly.fit(X_poly, YGuj)
lin2 = LinearRegression()
lin2.fit(X_poly, YGuj)
x = np.array([65]).reshape(-1, 1)
ans2 =int(lin2.predict(poly.fit_transform(x))) 
print(ans2)
# Out:
# 615404

# %%
casesgujtoday=ans2-YGuj[-1]
casesgujtoday
# Out:
# array([20802])

# %% [markdown]
# Task 6

# %%
print("Cases all over India on 4th May,2021 : ",casetoday)
print("Cases in Gujarat on 4th May,2021 : ",casesgujtoday)
perct = (casesgujtoday[0]/(casetoday[0]+casesgujtoday[0]))*100

plt.pie([perct.round(2),100-perct.round(2)],colors=['Blue','red'],labels=['Gujarat','India'],
        explode=(0.2,0),shadow=True,autopct='%1.1f%%')
plt.title("Covid cases on 4th May")
plt.legend()
plt.show()
# Out:
# Cases all over India on 4th May,2021 :  [320337]
# Cases in Gujarat on 4th May,2021 :  [20802]

# %% [markdown]
# TASK 7

# %%
bengaldata = combinedCSV.loc[combinedCSV['Province_State']=='West Bengal']
bengaldata
# Out:
#      FIPS Admin2  ... Incident_Rate Case_Fatality_Ratio
# 285   NaN    NaN  ...    577.572559            1.784758
# 285   NaN    NaN  ...    578.435932            1.783309
# 285   NaN    NaN  ...    578.179932            1.783752
# 285   NaN    NaN  ...    577.744229            1.784575
# 285   NaN    NaN  ...    577.970112            1.784225
# ..    ...    ...  ...           ...                 ...
# 285   NaN    NaN  ...    831.615095            1.369443
# 285   NaN    NaN  ...    849.195782            1.353268
# 285   NaN    NaN  ...    814.135804            1.387007
# 285   NaN    NaN  ...    866.779481            1.336471
# 285   NaN    NaN  ...    866.779481            1.336471
#
# [64 rows x 14 columns]

# %%
plt.plot(bengaldata['Last_Update'], bengaldata['Confirmed'], label = "Confirmed Cases", linestyle="-")
plt.plot(bengaldata['Last_Update'], bengaldata['Recovered'], label = "Recovered Cases", linestyle="--")
plt.plot(bengaldata['Last_Update'], bengaldata['Deaths'], label = "Deaths", linestyle="-.")
plt.xlabel("Days")
plt.ylabel("Number of Cases")
plt.title("West Bengal Covid Cases")
plt.legend()
plt.show()

# %%
databengal_1mar_1apr = bengaldata.head(31)
databengal_1apr_1may = bengaldata.iloc[31:61,:]

# %%
fig,axes=plt.subplots(figsize=(12,6),nrows=1,ncols=2)

axes[0].plot(databengal_1mar_1apr['Last_Update'],databengal_1mar_1apr['Confirmed'],color='b')
axes[0].set_xlabel('date')
axes[0].set_ylabel('no of cases')
axes[0].set_title('1 Mar - 1 April')

axes[1].plot(databengal_1apr_1may['Last_Update'],databengal_1apr_1may['Confirmed'],color='g')
axes[1].set_xlabel('date')
axes[1].set_ylabel('no of cases')
axes[1].set_title('1 April - 1 May')

plt.tight_layout()

# %% [markdown]
# Task 8

# %%
dataindia = combinedCSV.loc[combinedCSV['Country_Region']=='India']
dataindia
# Out:
#      FIPS Admin2  ... Incident_Rate Case_Fatality_Ratio
# 249   NaN    NaN  ...   1203.733011            1.235060
# 250   NaN    NaN  ...   1651.053766            0.805529
# 251   NaN    NaN  ...   1072.107627            0.332601
# 252   NaN    NaN  ...    611.030869            0.502367
# 253   NaN    NaN  ...    210.381535            0.586922
# ..    ...    ...  ...           ...                 ...
# 281   NaN    NaN  ...    856.708989            1.116927
# 282   NaN    NaN  ...           NaN                 NaN
# 283   NaN    NaN  ...    552.104404            1.002162
# 284   NaN    NaN  ...   1703.158995            1.462269
# 285   NaN    NaN  ...    866.779481            1.336471
#
# [2368 rows x 14 columns]

# %%
import seaborn as sns

dataindiamarch=dataindia.loc[dataindia['Last_Update']=='2021-03-02 05:23:30']
dataindiamarch.head(20)
dataindiamarch.reset_index(inplace = True)
maximumstate=dataindiamarch.sort_values(by=['Confirmed'],ascending=False)
maximumstate
fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=maximumstate.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="March Month Top 20 States Infected")
plt.show()

# %%
maximumstate
# Out:
#      FIPS Admin2  ... Incident_Rate Case_Fatality_Ratio
# 269   NaN    NaN  ...   3834.853869            1.488311
# 269   NaN    NaN  ...   3834.853869            1.488311
# 269   NaN    NaN  ...   3788.853335            1.492042
# 269   NaN    NaN  ...   3737.464810            1.495131
# 269   NaN    NaN  ...   3686.371061            1.497614
# ..    ...    ...  ...           ...                 ...
# 282   NaN    NaN  ...           NaN                 NaN
# 282   NaN    NaN  ...           NaN                 NaN
# 282   NaN    NaN  ...           NaN                 NaN
# 282   NaN    NaN  ...           NaN                 NaN
# 282   NaN    NaN  ...           NaN                 NaN
#
# [2368 rows x 14 columns]

# %%
dataindiamarch
# Out:
#     index  FIPS  ... Incident_Rate Case_Fatality_Ratio
# 0     249   NaN  ...   1203.733011            1.235060
# 1     250   NaN  ...   1651.053766            0.805529
# 2     251   NaN  ...   1072.107627            0.332601
# 3     252   NaN  ...    611.030869            0.502367
# 4     253   NaN  ...    210.381535            0.586922
# 5     254   NaN  ...   1885.153992            1.616374
# 6     255   NaN  ...   1062.690397            1.228198
# 7     256   NaN  ...    553.169927            0.058720
# 8     257   NaN  ...   3417.597487            1.706273
# 9     258   NaN  ...   3468.936170            1.446589
# 10    259   NaN  ...    423.212537            1.631424
# 11    260   NaN  ...    960.655766            1.125669
# 12    261   NaN  ...    788.746040            1.694540
# 13    262   NaN  ...    929.744413            1.547777
# 14    263   NaN  ...    310.893304            0.908439
# 15    264   NaN  ...   1408.469758            1.296343
# ...

# %%
import seaborn as sns

dataindiaapril = dataindia.loc[dataindia['Last_Update']=='2021-04-01 04:27:05']
dataindiaapril.head(20)
dataindiaapril.reset_index(inplace = True)
maximumstate2=dataindiaapril.sort_values(by=['Confirmed'],ascending=False)
maximumstate2

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=maximumstate2.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="May Month Top 20 States Infected")
plt.show()

# %%
import seaborn as sns

dataindiamay = dataindia.loc[dataindia['Last_Update']=='2021-05-01 04:20:47']
dataindiamay.head(20)
dataindiamay.reset_index(inplace = True)
maximumstate3=dataindiamay.sort_values(by=['Confirmed'],ascending=False)
maximumstate3

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=maximumstate3.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="May Month Top 20 States Infected")
plt.show()
